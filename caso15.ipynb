# %%
# %run ./FUNCIONES.ipynb

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import tabula
from tabula import read_pdf
import numpy as np
import pandas as pd
import re as regex
df = read_pdf('1088877.pdf', guess=False, stream=True, pages='all', multiple_tables=True,  pandas_options={'header':None})

# %%
pd.set_option('display.max_colwidth', -1)  #Veo hasta la última palabra
pd.set_option('display.max_rows', 1000)

# %%
for i in range(len(df)):
    print(i)
    df[i]
# Out:
# 0
#                                                                                       0  \
# 0   NaN
# 1   9/28/2017 RMW Receive and review and analyze client files
# 2   NaN
# 3   RMW Review and analyze case file
# 4   NaN
# 5   RMW Receive and review RO Summary regarding Association
# 6   NaN
# 7   ARS Emails with Attorney Russ Higgins at Knight regarding pre-trial
# 8   conference report
# 9   9/29/2017 ARS Telephone conference with attorney Higgins at Knight Law Group
# 10  regarding pre-trial conference
# 11  10/2/2017 ARS Review and revise pre trial conference statement; forward to opposing
# 12  counsel
# 13  ARS Prepare exhibit list
# 14  NaN
# 15  10/26/2017 ARS Receive and review consent order for magistrate
# 16  NaN
#
#             1         2
# 0   Hrs/Rate   Amount
# 1   2.10       1,050.00
# 2   500.00/hr  NaN
# 3   2.50       1,250.00
# 4   500 00/hr  NaN
# 5   0.30       150.00
# 6   500 00/hr  NaN
# 7   0.10       32.50
# 8   325.00/hr  NaN
# ...

# %%
df = df[0]

# %%
df = df.drop(df.head(1).index, axis=0)

# %%
rows_per_row = [1,1,1,2,2,2,1,1]
Date, Name, Descripcion = Date_Name_Descripcion(df.loc[:, 0], rows_per_row)
Hours, Rate = Hours_Rates(df.loc[:, 1])
Totals = Totals_func(df.loc[:, 2])

# %%
DF = pd.concat([Date.rename('Date'), Name.rename('Names'), Descripcion.rename('Description'),
                     Hours.rename('Hours'), Rate.rename('Rates'), Totals.rename('Totals')], axis=1)

# %%
DF
# Out:
#          Date Names  \
# 0  9/28/2017   RMW
# 1  9/28/2017   RMW
# 2  9/28/2017   RMW
# 3  9/28/2017   ARS
# 4  9/29/2017   ARS
# 5  10/2/2017   ARS
# 6  10/2/2017   ARS
# 7  10/26/2017  ARS
#
#                                                                                      Description  \
# 0  Receive and review and analyze client files
# 1  Review and analyze case file
# 2  Receive and review RO Summary regarding Association
# 3  Emails with Attorney Russ Higgins at Knight regarding pre-trial conference report
# 4  Telephone conference with attorney Higgins at Knight Law Group regarding pre-trial conference
# 5  Review and revise pre trial conference statement; forward to opposing counsel
# 6  Prepare exhibit list
# 7  Receive and review consent order for magistrate
#
#   Hours  Rates   Totals
# 0  2.10  500.0  1050.0
# 1  2.50  500.0  1250.0
# 2  0.30  500.0  150.0
# 3  0.10  325.0  32.5
# 4  1.00  325.0  32500.0
# 5  2.00  325.0  650.0
# 6  0.50  325.0  162.5
# ...

# %%
DF.to_excel(r"C:\Users\brian\Desktop\trabajillo\\1088877.xlsx", index=False)
