# %%
# %run ./FUNCIONES.ipynb

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import tabula
from tabula import read_pdf
import numpy as np
import pandas as pd
import re as regex
df = read_pdf('1088881.pdf', guess=False, stream=True, pages='all', multiple_tables=True,  pandas_options={'header':None})

# %%
pd.set_option('display.max_colwidth', -1)  #Veo hasta la última palabra
pd.set_option('display.max_rows', 1000)

# %%
df[0] = df[0].drop(df[0].head(10).index, axis=0)

# %%
df[0] = df[0].drop(df[0].tail(8).index, axis=0)

# %%
df[0]
# Out:
#                                                                                           0  \
# 10  9/25/2017 RMW Receive and review and analyze client files
# 11  NaN
# 12  RE Draft, review and revise Notice in Lieu of Service of Subpoena to Appear at
# 13  Trial; Draft, review and revise Letter and Notice to Defendants to Produce
# 14  Financial Information Showing Viability to Pay Punitive Damages; Draft,
# 15  review and revise proof(s) of service; Draft, review and revise email to
# 16  Nationwide regarding service; Serve same
# 17  9/26/2017 JRU Draft, review and revise Trial Readiness Conference report
# 18  NaN
# 19  9/27/2017 JRU Draft, review and revise Trial Readiness Conference report
# 20  NaN
# 21  9/28/2017 RE Receive and review email from co-counsel regarding objections to Notice of
# 22  Deposition;Draft, review and revise email to co-counsel notifying case settled
# 23  9/29/2017 ARS Travel to and from and attend Trial Readiness Conference, give courtesy
# ...

# %%
rows_per_row = [1,5,1,1,2,2,3]
DF = dnd_hr_t(df[0], rows_per_row)
# Out:
# 0    950.0
# 1    52.5
# 2    875.0
# 3    150.0
# 4    17.5
# 5    325.0
# 6    17.5
# Name: 2, dtype: object

# %%
DF
# Out:
#         Date Names  \
# 0  9/25/2017  RMW
# 1  9/25/2017  RE
# 2  9/26/2017  JRU
# 3  9/27/2017  JRU
# 4  9/28/2017  RE
# 5  9/29/2017  ARS
# 6  10/2/2017  RE
#
#                                                                                                                                                                                                                                                                                                                                         Description  \
# 0  Receive and review and analyze client files
# 1  Draft, review and revise Notice in Lieu of Service of Subpoena to Appear at Trial; Draft, review and revise Letter and Notice to Defendants to Produce Financial Information Showing Viability to Pay Punitive Damages; Draft, review and revise proof(s) of service; Draft, review and revise email to Nationwide regarding service; Serve same
# 2  Draft, review and revise Trial Readiness Conference report
# ...

# %%
DF.to_excel(r"C:\Users\brian\Desktop\trabajillo\\1088881.xlsx", index=False)
